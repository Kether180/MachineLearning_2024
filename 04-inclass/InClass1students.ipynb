# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # In-class - Week 1
#
# <article class="message">
#     <div class="message-body">
#         <strong>Overview of tasks</strong>
#         <ul style="list-style: none;">
#             <li>
#             <a href="#dist">Task 1: Distances and inner products</a>
#             </li>
#             <li>
#             <a href="#eval">Task 2: Evaluating models</a>
#             </li>
#             <li>
#             <a href="#modeleq">Task 3: Model equations</a>
#             </li>
#         </ul>
#     </div>
# </article>
#
# <article class="message task"><a class="anchor" id="dist"></a>
#     <div class="message-header">
#         <span>Task 1: Distances and inner products</span>
#         <span class="has-text-right">
#           <i class="bi bi-lightbulb-fill"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# Given the the  vectors $a,b,c \in \mathbb{R}^5$:
# $a = [180, 70, 10, 0, 4]$$b = [165, 55, 8, 1, 7]$$c = [175, 60, 9, 0, 3]$1. Calculate the Euclidean distance between vectors $a$ and $b$ using the distance formula:
#
# $||a - b|| = \sqrt{((a₁ - b₁)² + (a₂ - b₂)² + ... + (aₙ - bₙ)²)}$2. Calculate the Euclidean distance as in exercise 1, but this time use the inner product:
#
# $||a - b|| = \sqrt{(a - b) · (a - b)}$**Note:** (Hint: first find $(a-b)$)
#
# 3. The outcome of the two exercises should give you the same result. Reflect on the properties of inner products demonstrated in the second exercise.
#
# 4. Using your preferred formula find the vectors which are at the lowest Euclidean distance from each other.
#
#
# $||a - b|| = \sqrt{((a₁ - b₁)² + (a₂ - b₂)² + ... + (aₙ - bₙ)²)}$$||a - b|| = \sqrt{(a - b) · (a - b)}$
#
# </div></article>
#
# <article class="message task"><a class="anchor" id="eval"></a>
#     <div class="message-header">
#         <span>Task 2: Evaluating models</span>
#         <span class="has-text-right">
#           <i class="bi bi-lightbulb-fill"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# You are given the following dataset consisting of training inputs $x$ and training labels, $y$:
# $x_1 = 2, y_1 = 5$$x_2 = 3, y_2 = 7$$x_3 = 4, y_3 = 9$Assume you are asked to evaluate two models $f$ and $g$ defined as:
# $f(x) = 3x^2 - 2x + 1$$g(x) = 2x^2 + 4x + 3$In the following steps you have to calculate the least squares loss of the models $f$ and $g$ on the training data:
# Loss Function:
# $(\mathcal{L} = \frac{1}{N} \sum_{i=1}^{N} (y_i - f(x_i))^2)$$(\mathcal{L} = \frac{1}{N} \sum_{i=1}^{N} (y_i - g(x_i))^2)$1. Calculate the loss $\mathcal{L}_f$
#
# 2. Calculate the loss $\mathcal{L}_g$
#
# 3. Compare the calculated losses $(\mathcal{L}_f)$ and $(\mathcal{L}_g)$ and decide which model is the best performing one.
#
#
#
#
# </div></article>
#
# <article class="message task"><a class="anchor" id="modeleq"></a>
#     <div class="message-header">
#         <span>Task 3: Model equations</span>
#         <span class="has-text-right">
#           <i class="bi bi-lightbulb-fill"></i><i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# 1. Consider the following linear model: $f_x(\sigma) = x\sigma + b$. Which part of the equation represents the model parameters? /(select all correct answers)
#
# A) $(f_x(\sigma))$
# B) $(\sigma)$
# C) $(x)$
# D) $(b)$
# 2. Considering the formula above, $f_x(\sigma) = x\sigma + b$, which variable represents the input?
#
# A) $(f_x(\sigma))$
# B) $(\sigma)$
# C) $(x)$
# D) $(b)$
# 3. What does the variable $\mathbf{v}$ represent in the equation $\mathbf{v}' = A\mathbf{v} + \mathbf{b}$.
#
# A) The transformed vector
# B) The input vector
# C) The parameters
# D) The bias vector
# 4. In the multivariate function equation $f(x, y) = 3x^2 + 2xy + y^2$, what does $f(x, y)$ represent?
#
# A) Model parameters
# B) An input variables
# C) The output variable
# D) A bias term
# 5. Consider the plane equation $2x - 3y + 5z = 7$. Which of the following equations correspond to the same plane equation?
#
# A) $(f(x, y, z) = 2x - 3y + 5z)$
# B) $(f(x, y, z) = 7x - 3y + 5z)$
# C) $(f(x, y, z) = 2x + 3y - 5z)$
# D) $(f(x, y, z) = 2x - 3y + 5z - 7)$
#
#
# </div></article>
#
# [**** You can find all solutions here. Edit this cell to get the results ****]
# <!--
# $a$
# $||a - b|| = \sqrt{((180 - 165)² + (70 - 55)² + (10 - 8)² + (0 - 1)² + (4 - 7)²)}$
# $= \sqrt{(225 + 225 + 4 + 1 + 9)}$
# $= \sqrt{464}$
# $≈ 21.54$
# 1.2 Euclidean distance using the inner product:
#
# $a$
# $\sqrt{(a - b) · (a - b)} = \sqrt{(15 * 15 + 15 * 15 + 2 * 2 + (-1) * (-1) + (-3) * (-3))}$
# $= \sqrt{464}$
# $≈ 21.54$
# 1.4 Finding the vectors at the lowest Euclidean distance from each other:
#
# $a$
# $a - b = [180 - 165, 70 - 55, 10 - 8, 0 - 1, 4 - 7] = [15, 15, 2, -1, -3]$
# $\sqrt{(a - b) · (a - b)} = \sqrt{(15 * 15 + 15 * 15 + 2 * 2 + (-1) * (-1) + (-3) * (-3))}$
# $= \sqrt{464}$
# $≈ 21.54$
#
# $a$
# $a - c = [180 - 175, 70 - 60, 10 - 9, 0 - 0, 4 - 3] = [5, 10, 1, 0, 1]$
# $\sqrt{(a - c) · (a - c)} = \sqrt{5 * 5 + 10 * 10 + 1 * 1 + 0 * 0 + 1 * 1}$
# $ = \sqrt{127}$
# $≈ 11.27$
#
# $b$
# $b - c = [165 - 175, 55 - 60, 8 - 9, 1 - 0, 7 - 3] = [-10, -5, -1, 1, 4]$
# $\sqrt{(b - c) · (b - c)} = sqrt{(-10) * (-10) + (-5) * (-5) + (-1) * (-1) + 1 * 1 + 4 * 4}$
# $ = \sqrt{143}$
# $≈ 11.96$
#
# $a$
#
#
#
#
# $\mathcal{L}_f$
# $𝑥=2: 𝑓(2)=3(2)^2−2(2)+1=9$
# $𝑥=3: 𝑓(3)=3(3)^2−2(3)+1=22$
# $𝑥=4: 𝑓(4)=3(4)^2−2(4)+1=41$
# $L_f = \frac{1}{3} [(5 - 9)^2 + (7 - 22)^2 + (9 - 41)^2]$
# $L_f = \frac{1265}{3}$
# $L_f = 421.66666$
# $\mathcal{L}_g$
# $𝑥=2: 𝑔(2)=2(2)^2−4(2)+3=3$
# $𝑥=3: 𝑔(3)=2(3)^2−4(3)+3=9$
# $𝑥=4: 𝑔(4)=4(4)^2−4(4)+3=51$
# $L_g = \frac{1}{3} [(5 - 3)^2 + (7 - 9)^2 + (9 - 51)^2]$
# $L_g = \frac{1772}{3}$
# $L_g = 590.66666$
# 2.3 Comparing losses
#
# $L_f = 421.66666$
# $L_g = 590.66666$
#
#
#
#
# 3.1 C) and  D)
#
# 3.2 B)
#
# 3.3 B)
#
# 3.4 C)
#
# 3.5 D)
#
# -->
