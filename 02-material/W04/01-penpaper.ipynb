# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Pen and paper exercises
# These exercises should be completed using only pen and paper.
# <article class="message task"><a class="anchor" id="space"></a>
#     <div class="message-header">
#         <span>Task 1: Smallest vector space</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights easy"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# Suppose $\mathbf{P}$ is a plane through $(0, 0, 0)$ and $\mathbf{L}$ is a line
# through $(0, 0, 0)$. The smallest vector space containing both $\mathbf{P}$ and
# $\mathbf{L}$ is either ____ or ____.
#
#
# </div></article>
#
# <article class="message task"><a class="anchor" id="systems"></a>
#     <div class="message-header">
#         <span>Task 2: Solutions</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# For which vectors $(b_1, b_2, b_3)$ do these systems have a solution?
#
# $$
# a)\quad \begin{bmatrix}
# 1 & 1 & 1\\
# 0 & 1 & 1\\
# 0 & 0 & 1\\
# \end{bmatrix}
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1\\
# b_2\\
# b_3\\
# \end{bmatrix}
# $$
#
# $$
# b)\quad \begin{bmatrix}
# 1 & 1 & 1\\
# 0 & 1 & 1\\
# 0 & 0 & 0\\
# \end{bmatrix}
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1\\
# b_2\\
# b_3\\
# \end{bmatrix}
# $$
#
# $$
# c)\quad \begin{bmatrix}
# 1 & 1 & 1\\
# 0 & 0 & 1\\
# 0 & 0 & 1\\
# \end{bmatrix}
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# b_1\\
# b_2\\
# b_3\\
# \end{bmatrix}
# $$
#
#
# </div></article>
#
# <article class="message task"><a class="anchor" id="truefalse"></a>
#     <div class="message-header">
#         <span>Task 3: True or false</span>
#         <span class="has-text-right">
#           <i class="bi bi-stoplights medium"></i>
#         </span>
#     </div>
# <div class="message-body">
#
#
# True or false (with a counterexample if false):
# 1. The vectors $\mathbf{b}$ that are not in the column space $\mathbf{C}(A)$
# form a subspace.
# 2. If $\mathbf{C}(A)$ contains only the zero vector, then $A$ is the zero matrix.
# 3. The column space of $2A$ equals the column space of $A$.
# 4. The column space of $A-I$ equals the column space of $A$ (test this).
#
#
#
# </div></article>
